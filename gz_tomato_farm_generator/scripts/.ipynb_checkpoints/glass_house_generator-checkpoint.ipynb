# %%
# Out:
# param "~seed" = "1000"
# param "~model_name_prefix" = "tomato"
# param "~glasshouse_per_line" = "1"
# param "~lines_of_glasshouse" = "1"
# param "~row_count" = "10"
# param "~row_length" = "10"
# param "~row_dist" = "0.5"
# param "~crop_dist" = "0.5"
# param "~world_name" = "6mx11m"

# %%
#Codigo referente a la ruta del archivo
OUT_PATH = Path(get_param('~out_path', str(Path().resolve().parent / 'generated/farm_') + WORLD_NAME)).resolve()
#OUT_PATH = Path(get_param('~out_path', str(Path().resolve().parent / 'generated'))).resolve()
#Código referente a la ruta de los templates
WORLD_TEMPLATE = Path(get_param('~world_template', str(Path().resolve().parent / 'templates/tomato_world_gazebo_classic_and_sim'))).resolve()
MODEL_TEMPLATE = Path(get_param('~model_template', str(Path().resolve().parent / 'templates/tomato_model_gazebo_classic_and_sim'))).resolve()

shutil.rmtree(OUT_PATH, ignore_errors=True)
np.random.seed(SEED)
# Out:
# param "~out_path" = "/home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m"
# param "~world_template" = "/home/paul/dogtooth_ws/src/gz_tomato_farm_generator/templates/tomato_world_gazebo_classic_and_sim"
# param "~model_template" = "/home/paul/dogtooth_ws/src/gz_tomato_farm_generator/templates/tomato_model_gazebo_classic_and_sim"

# %%
# helper class to build the markers.json
class Markers:
    markers = []
    last_id = 0

    @staticmethod
    def next_id():
        Markers.last_id += 1
        return Markers.last_id

    @staticmethod
    def reset():
        Markers.markers = []
    
    @staticmethod
    def add_plant(x, y, z):
        id = Markers.next_id()
        Markers.markers.append({
            'marker_type': 'PLANT',
            'id': id,
            'translation': [x, y, z]
        })
        return id
    

    @staticmethod
    def add_fruit(x, y, z, plant_id):
        id = Markers.next_id()
        Markers.markers.append({
            'marker_type': 'FRUIT',
            'id': id,
            'translation': [x, y, z],
            'plant_id': plant_id
        })
        return id
    
    @staticmethod
    def dumps():
        return json.dumps(Markers.markers, indent=4)

# %%
models = {'list': []}
Markers.reset()

for x in range(ROW_COUNT):
    for y in range(CROP_NUM_IN_A_ROW):
        model_name = 'tomato_{}'.format(x * CROP_NUM_IN_A_ROW + y)

        cookiecutter(str(MODEL_TEMPLATE),
                     output_dir=str(OUT_PATH),
                     overwrite_if_exists=True, no_input=True,
             extra_context={'world_name': WORLD_NAME, 
                            'model_name': model_name, 'models': "models"})

        x_pos, y_pos, z_pos = x * ROW_DIST - ((ROW_COUNT - 1)*ROW_DIST)/2, y * CROP_DIST - ROW_LENGTH/2, 0
        models['list'].append({
            'model': model_name,
            'name': model_name,
            'pose': '{} {} 0 0 0 0'.format(x_pos, y_pos)
        })
        x_pos += np.random.uniform(-0.1, 0.1)
        y_pos += np.random.uniform(-0.1, 0.1)
        seed = np.random.randint(10000)
        dir = (OUT_PATH / 'models' / WORLD_NAME / model_name).resolve()
        dir_blender = (Path.cwd() / '../blender').resolve()
        blend = str(dir_blender / 'tomato_gen.blend')
        script = str(dir_blender / 'tomato_gen.py')
        ! blender $blend --background --python $script -- --model_dir $dir --seed $seed

        plant_id = Markers.add_plant(x_pos, y_pos, z_pos)
        with open(dir / 'markers.json') as markers_file:
            plant_markers = json.load(markers_file)
            for marker in plant_markers:
                if marker['marker_type'] == 'FRUIT':
                    Markers.add_fruit(
                        marker['translation'][0] + x_pos,
                        marker['translation'][1] + y_pos,
                        marker['translation'][2] + z_pos,
                        plant_id
                    )
# Out:
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_0/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_1/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_2/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_3/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_4/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_5/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_6/meshes/tomato.dae
# Info: Exported 5 Objects
# Info: Exported 5 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_7/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_8/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_9/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_10/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_11/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_12/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_13/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_14/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_15/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_16/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_17/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_18/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_19/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_20/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_21/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_22/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_23/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_24/meshes/tomato.dae
# Info: Exported 10 Objects
# Info: Exported 10 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_25/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_26/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_27/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_28/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_29/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_30/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_31/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_32/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# ...
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_46/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_47/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_48/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_49/meshes/tomato.dae
# Info: Exported 5 Objects
# Info: Exported 5 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_50/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_51/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_52/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_53/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_54/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_55/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/paul/dogtooth_ws/src/gz_tomato_farm_generator/generated/farm_6mx11m/models/6mx11m/tomato_56/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Read prefs: /home/paul/.config/blender/3.0/config/userpref.blend
# Color management: scene view "Filmic" not found, setting default "Standard".

# %%
cookiecutter(str(WORLD_TEMPLATE),
             output_dir=str(OUT_PATH), 
             overwrite_if_exists=True, 
             no_input=True,
             extra_context={'world_name': WORLD_NAME, 'models': models, 'farm_area_x': str(FARM_SIZE[0]), 
                            'farm_area_y': str(FARM_SIZE[1]), 'worlds': "worlds"})

# %%
with open(OUT_PATH / 'models' / WORLD_NAME / 'markers.json', 'w') as outfile:
    json.dump(Markers.markers, outfile, indent=4, sort_keys=True)
