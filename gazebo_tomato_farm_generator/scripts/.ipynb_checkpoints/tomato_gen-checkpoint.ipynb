# %%
import rclpy
from rclpy.node import Node
import sys
import numpy as np
import collections
from pathlib import Path
import json
import shutil
from cookiecutter.main import cookiecutter
import math

rclpy.init(args=sys.argv)
node = rclpy.create_node('deneme')

# %%
def get_param(name, default):
    try:
        value = node.declare_parameter(name, default).value
    except ConnectionRefusedError:
        value = default
    print('param "{}" = "{}"'.format(name, value))
    return value

SEED = int(get_param('~seed', '1000'))
WORLD_NAME = get_param('~world_name', 'tomato_field')
MODEL_NAME_PREFIX = get_param('~model_name_prefix', 'tomato')
ROW_COUNT = int(get_param('~row_count', '12'))
ROW_LENGTH = int(get_param('~row_length', '10'))
ROW_DIST = float(get_param('~row_dist', '2.0'))
CROP_DIST = float(get_param('~crop_dist', '0.7'))
CROP_NUM_IN_A_ROW = int(math.floor(ROW_LENGTH/CROP_DIST + 1))
FARM_SIZE = [float((ROW_COUNT + 1) * ROW_DIST), float(ROW_LENGTH + 2 * ROW_DIST)]
# Out:
# param "~seed" = "1000"
# param "~world_name" = "tomato_field"
# param "~model_name_prefix" = "tomato"
# param "~row_count" = "12"
# param "~row_length" = "10"
# param "~row_dist" = "2.0"
# param "~crop_dist" = "0.7"

# %%
OUT_PATH = Path(get_param('~out_path', str(Path().resolve().parent / 'generated/test04'))).resolve()
WORLD_TEMPLATE = Path(get_param('~world_template', str(Path().resolve().parent / 'templates/tomato_world'))).resolve()
MODEL_TEMPLATE = Path(get_param('~model_template', str(Path().resolve().parent / 'templates/tomato_model'))).resolve()
#OUT_PATH = Path(get_param('~out_path', '/home/ayilmaz/random_farm_ws/fields_ignition/generated/test01')).resolve()
#MODEL_TEMPLATE = Path(get_param('~model_template', '/home/ayilmaz/random_farm_ws/fields_ignition/templates/tomato_model')).resolve()
#WORLD_TEMPLATE = Path(get_param('~world_template', '/home/ayilmaz/random_farm_ws/fields_ignition/templates/tomato_world')).resolve()

shutil.rmtree(OUT_PATH, ignore_errors=True)
np.random.seed(SEED)
# Out:
# param "~out_path" = "/home/ayilmaz/random_farm_ws/fields_ignition/generated/test04"
# param "~world_template" = "/home/ayilmaz/random_farm_ws/fields_ignition/templates/tomato_world"
# param "~model_template" = "/home/ayilmaz/random_farm_ws/fields_ignition/templates/tomato_model"

# %%
# helper class to build the markers.json
class Markers:
    markers = []
    last_id = 0

    @staticmethod
    def next_id():
        Markers.last_id += 1
        return Markers.last_id

    @staticmethod
    def reset():
        Markers.markers = []
    
    @staticmethod
    def add_plant(x, y, z):
        id = Markers.next_id()
        Markers.markers.append({
            'marker_type': 'PLANT',
            'id': id,
            'translation': [x, y, z]
        })
        return id
    

    @staticmethod
    def add_fruit(x, y, z, plant_id):
        id = Markers.next_id()
        Markers.markers.append({
            'marker_type': 'FRUIT',
            'id': id,
            'translation': [x, y, z],
            'plant_id': plant_id
        })
        return id
    
    @staticmethod
    def dumps():
        return json.dumps(Markers.markers, indent=4)

# %%
models = {'list': []}
Markers.reset()

for x in range(ROW_COUNT):
    for y in range(CROP_NUM_IN_A_ROW):
        model_name = 'tomato_{}'.format(x * CROP_NUM_IN_A_ROW + y)

        cookiecutter(str(MODEL_TEMPLATE),
             output_dir=str(OUT_PATH), 
             overwrite_if_exists=True, 
             no_input=True,
             extra_context={'world_name': WORLD_NAME, 'model_name': model_name})

        x_pos, y_pos, z_pos = x * ROW_DIST - ((ROW_COUNT - 1)*ROW_DIST)/2, y * CROP_DIST - ROW_LENGTH/2, 0
        models['list'].append({
            'model': model_name,
            'name': model_name,
            'pose': '{} {} 0 0 0 0'.format(x_pos, y_pos)
        })
        x_pos += np.random.uniform(-0.1, 0.1)
        y_pos += np.random.uniform(-0.1, 0.1)
        seed = np.random.randint(10000)
        dir = (OUT_PATH / WORLD_NAME / model_name).resolve()
        dir_blender = (Path.cwd() / '../blender').resolve()
        blend = str(dir_blender / 'tomato_gen.blend')
        script = str(dir_blender / 'tomato_gen.py')
        ! blender $blend --background --python $script -- --model_dir $dir --seed $seed

        plant_id = Markers.add_plant(x_pos, y_pos, z_pos)
        with open(dir / 'markers.json') as markers_file:
            plant_markers = json.load(markers_file)
            for marker in plant_markers:
                if marker['marker_type'] == 'FRUIT':
                    Markers.add_fruit(
                        marker['translation'][0] + x_pos,
                        marker['translation'][1] + y_pos,
                        marker['translation'][2] + z_pos,
                        plant_id
                    )
# Out:
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_0/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_1/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_2/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_3/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_4/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_5/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_6/meshes/tomato.dae
# Info: Exported 5 Objects
# Info: Exported 5 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_7/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_8/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_9/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_10/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_11/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_12/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_13/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_14/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_15/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_16/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_17/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_18/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_19/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_20/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_21/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_22/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_23/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_24/meshes/tomato.dae
# Info: Exported 10 Objects
# Info: Exported 10 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_25/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_26/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_27/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_28/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_29/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_30/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_31/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_32/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_33/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_34/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# ...
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_168/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_169/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_170/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_171/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_172/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_173/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_174/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_175/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_176/meshes/tomato.dae
# Info: Exported 9 Objects
# Info: Exported 9 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_177/meshes/tomato.dae
# Info: Exported 7 Objects
# Info: Exported 7 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_178/meshes/tomato.dae
# Info: Exported 8 Objects
# Info: Exported 8 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB
# Color management: using fallback mode for management
# Color management: Error could not find role data role.
# Blender 3.0.1
# Color management: scene view "Filmic" not found, setting default "Standard".
# Read blend: /home/ayilmaz/random_farm_ws/fields_ignition/blender/tomato_gen.blend
# Color management: scene view "Filmic" not found, setting default "Standard".
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Color management: image colorspace "Non-Color" not found, will use default instead.
# Collada export to: /home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field/tomato_179/meshes/tomato.dae
# Info: Exported 6 Objects
# Info: Exported 6 Objects
#
# Blender quit
# Error: Not freed memory blocks: 7, total unfreed memory 0.001198 MB

# %%
cookiecutter(str(WORLD_TEMPLATE),
             output_dir=str(OUT_PATH), 
             overwrite_if_exists=True, 
             no_input=True,
             extra_context={'world_name': WORLD_NAME, 'models': models, 'farm_area_x': str(FARM_SIZE[0]), 'farm_area_y': str(FARM_SIZE[1])})
# Out:
# '/home/ayilmaz/random_farm_ws/fields_ignition/generated/test04/tomato_field'

# %%
with open(OUT_PATH / WORLD_NAME / 'markers.json', 'w') as outfile:
    json.dump(Markers.markers, outfile, indent=4, sort_keys=True)
